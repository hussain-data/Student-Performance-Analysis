# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Imran/Student Performance Analysis/StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
categories = [ 'gender', 'race/ethnicity', 'parental level of education', 'lunch',
       'test preparation course']
for category in categories:
  print(df[category].value_counts())
  print('♠' * 30)
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64
# ♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64
# ♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64
# ♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64
# ♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64
# ♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠♠

# %% [markdown]
# ### Univariate Plots

# %% [markdown]
# ### pal - palette of colors

# %%
pal = ['#EC4A3C','#F27712','#6CF3C7','#489772','#BA87B0', '#4D3947']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
sns.barplot(x=df['gender'].value_counts().index, y=df['gender'].value_counts(), hue=df['gender'].value_counts().index,legend=False)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df.mean(numeric_only=True)
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
plt.figure(figsize=(4,3))
sns.barplot(x=df.mean(numeric_only=True).index,
            y=df.mean(numeric_only=True),hue=df.mean(numeric_only=True),   
            legend=False)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
plt.figure(figsize=(4,3))
ax = sns.barplot(x=df.mean(numeric_only=True).index,
            y=df.mean(numeric_only=True), hue=df.mean(numeric_only=True).index, legend=False,
            palette=pal[2:5])

ax.patches
# Out:
# <Axes.ArtistList of 3 patches>

# %%
plt.figure(figsize=(4,3))
ax = sns.barplot(x=df.mean(numeric_only=True).index,
            y=df.mean(numeric_only=True),hue=df.mean(numeric_only=True).index,legend=False,
            palette=pal[2:5])

for bar in ax.patches:
  bar.set_linewidth(3)
  bar.set_edgecolor('black')

plt.title('Students Average Scores', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Students Average Scores')

# %%
plt.figure(figsize=(4,3))
ax = sns.barplot(y=df.mean(numeric_only=True).index,
            x=df.mean(numeric_only=True),hue=df.mean(numeric_only=True).index,legend=False,
            palette=pal[2:5],)

for bar in ax.patches:
  bar.set_linewidth(3)
  bar.set_edgecolor('black')

  plt.title('\nStudents Average Score\n', fontsize=20)
  plt.xlabel('Score\n')

# %%
plt.figure(figsize=(4,3))
sns.barplot(data=df,
            y='math score',
            x='gender', hue='gender', legend=False,
            palette=pal[3:5],)
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
plt.figure(figsize=(4,3))
sns.barplot(data=df,
            x='math score',
            y='gender', hue='gender', legend=False,
            palette=pal[3:5],)
# Out:
# <Axes: xlabel='math score', ylabel='gender'>

# %% [markdown]
# ### Lineplot

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
plt.figure(figsize=(12,4))
sns.lineplot(data=df, x='reading score', y='math score', color=pal[0])
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.lineplot(data=df, x='reading score', y='math score', color=pal[0],
             errorbar=None)
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.lineplot(data=df, x='reading score', y='math score', color=pal[0],
             hue='writing score',)
plt.show()

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
plt.figure(figsize=(12,4))
sns.lineplot(data=df, x='reading score', y='math score', palette=pal[:-1],
             hue='race/ethnicity')
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.lineplot(data=df, x='reading score', y='math score', palette=pal[-2:],
             hue='gender', lw=4)
plt.show()

# %% [markdown]
# ### Histplot

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=df, x='math score', stat='count',
             color=pal[np.random.randint(0,5)])
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=df, x='math score',
             bins=30,
             color=pal[np.random.randint(0,5)])
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=df, x='math score', element='step',
             bins=10,
             color=pal[np.random.randint(0,5)])
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=df, x='math score', element='poly', #'poly'
             bins=10,
             color=pal[np.random.randint(0,5)])
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=df, x='math score',
             bins=100,
             cumulative=True,
             color=pal[np.random.randint(0,5)])
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=df, x='math score',
             bins=100, hue='parental level of education',
             cumulative=True, palette=pal)
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=df, x='math score',
             bins=100, hue='parental level of education',
             cumulative=True, kde=True, palette=pal)
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=df, x='math score', line_kws={'lw':5},
             bins=100, hue='parental level of education',
             cumulative=True, kde=True, palette=pal)
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=df, x='math score', line_kws={'lw':5},
             bins=30, hue='gender', multiple='layer',
             kde=True)
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
plt.figure(figsize=(4,3))
sns.histplot(data=df, x='math score', line_kws={'lw':5},
             bins=30, hue='gender', multiple='stack',
             kde=True)
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %% [markdown]
# ### kdeplot

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
plt.figure(figsize=(4,3))
sns.kdeplot(data=df, x='writing score',
            color=pal[np.random.randint(0,5)])
# Out:
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
plt.figure(figsize=(4,3))
sns.kdeplot(data=df, x='writing score',  bw_method=.15,
            fill=True,
            color=pal[np.random.randint(0,5)])
# Out:
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
plt.figure(figsize=(4,3))
sns.kdeplot(data=df, x='writing score', bw_method=.05,
            hue='race/ethnicity',
            palette=pal[:-1])
# Out:
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
plt.figure(figsize=(4,3))
sns.kdeplot(data=df, x='writing score', bw_method=.45,
            hue='race/ethnicity', lw=4,
            palette=pal[:-1])
# Out:
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
plt.figure(figsize=(4,3))
ax = sns.kdeplot(data=df, x='writing score', bw_method=.25,
            hue='race/ethnicity', lw=4, multiple='stack',
            palette=pal[:-1])
sns.move_legend(ax, 'upper left')

# %% [markdown]
# ### boxplot

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
plt.figure(figsize=(4,3))
sns.boxplot(data=df, x='reading score')
# Out:
# <Axes: xlabel='reading score'>

# %%
plt.figure(figsize=(3,3))
sns.boxplot(data=df, x='reading score',
            y='test preparation course')
# Out:
# <Axes: xlabel='reading score', ylabel='test preparation course'>

# %%
plt.figure(figsize=(3,3))
sns.boxplot(data=df, x='reading score',
            y='test preparation course',
            linewidth=3)
# Out:
# <Axes: xlabel='reading score', ylabel='test preparation course'>

# %%
plt.figure(figsize=(3,3))
sns.boxplot(data=df, x='reading score',
            y='test preparation course',
            linewidth=3,
            whis=2)
# Out:
# <Axes: xlabel='reading score', ylabel='test preparation course'>

# %% [markdown]
# ### violin plot

# %%
plt.figure(figsize=(3,3))
sns.violinplot(data=df, y='reading score', color=pal[4])
# Out:
# <Axes: ylabel='reading score'>

# %%
plt.figure(figsize=(4,3))
sns.violinplot(data=df, y='reading score', x='gender',
               hue='test preparation course',
               split=True,
               palette=pal[-2:])
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>

# %%
plt.figure(figsize=(4,3))
sns.violinplot(data=df, y='reading score', x='gender',
               hue='test preparation course', split=True,
               inner='quartile', palette=pal[-2:])
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>

# %%
plt.figure(figsize=(4,3))
sns.violinplot(data=df, y='reading score', x='gender',
               hue='test preparation course', split=True,
               inner='quartile', bw_adjust=.2, palette=pal[-2:])
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>

# %%
plt.figure(figsize=(4,3))
sns.violinplot(data=df, y='reading score', x='gender',
               hue='test preparation course', split=True,
               inner='stick', bw_adjust=.05, palette=pal[-2:])
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>

# %% [markdown]
# ### boxen plot

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
plt.figure(figsize=(4,3))
sns.boxenplot(data=df,x='writing score', color=pal[3])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxenplot(data=df, x='writing score',
              showfliers=False, color=pal[3])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxenplot(data=df,x='writing score',
              showfliers=True,
              y='gender', hue='gender', palette=pal[1:3])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.boxenplot(data=df,x='writing score',
              y='gender', hue='gender',
              showfliers=True,
              k_depth=10, # number of boxes
              width_method='exponential',  # proportion of data covered
              palette=[pal[0], pal[3]])
plt.show()

# %% [markdown]
# ### swarm plot

# %%
plt.figure(figsize=(4,3))
sns.swarmplot(data=df, x='reading score',
              y='gender',hue='gender',size=2.8, palette=[pal[0], pal[3]])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.swarmplot(data=df, x='reading score',
              y='gender',hue='gender',
              size=2.8, palette=[pal[0], pal[3]])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.swarmplot(data=df, x='gender',
              y='reading score', hue='gender',
              size=2.8, palette=[pal[0], pal[3]])
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.swarmplot(data=df, x='gender',
              y='reading score',
              hue='lunch',
              size=3, palette=[pal[0], pal[3]])
plt.show()

# %% [markdown]
# ### count plot

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=df, x='gender', hue='gender', palette=[pal[0], pal[3]])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=df, x='race/ethnicity',hue='race/ethnicity',  palette=pal[:5])
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %%
df['race/ethnicity'].value_counts()#.index
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
labels = df['race/ethnicity'].value_counts().index

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=df, x='race/ethnicity',hue='race/ethnicity', palette=pal[:5], order=labels)
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=df, x='lunch',hue='lunch', palette=pal[-2:])
# Out:
# <Axes: xlabel='lunch', ylabel='count'>

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=df, x='lunch', hue='gender',
              dodge=True, palette=pal[-2:])
# Out:
# <Axes: xlabel='lunch', ylabel='count'>

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=df, x='lunch', hue='gender', dodge=False,
              palette=pal[-2:])
# Out:
# <Axes: xlabel='lunch', ylabel='count'>

# %% [markdown]
# ### Figure Level Plot

# %% [markdown]
# ### seaborn displot

# %%
sns.displot(data=df, x='math score', kde=True,
            color=pal[np.random.randint(0,5)])

# %%
sns.displot(data=df, x='math score', kde=True, col='gender',
            height=3.5,
            color=pal[np.random.randint(0,5)])

# %%
sns.displot(data=df, x='math score', kde=True, col='gender',
            row='lunch', height=3.5, linewidth=2, line_kws={'lw':5},
            color=pal[np.random.randint(0,5)])

# %%
sns.displot(data=df, x='math score', kde=True, col='gender',
            row='lunch',  hue='test preparation course',
            height=3.5, linewidth=2, line_kws={'lw':5},
            palette=[pal[np.random.randint(0,5)],
                      pal[np.random.randint(0,5)]])

# %% [markdown]
# ### Figure Level

# %% [markdown]
# ### Seaborn catplot

# %%
sns.catplot(data=df, kind='strip', x='math score', y='lunch',hue='lunch',
            height=3.5,
            palette=[pal[np.random.randint(0,5)],
                      pal[np.random.randint(0,5)]])

# %%
sns.catplot(data=df, kind='swarm', x='math score', y='lunch', col='gender',hue='lunch',
            height=3.5,size=3,
            palette=[pal[np.random.randint(0,5)],
                      pal[np.random.randint(0,5)]])

# %%
sns.catplot(data=df, kind='swarm', x='math score', y='lunch', col='gender',
            hue='test preparation course', height=3.5, aspect=.8,s=6,
            palette=[pal[np.random.randint(0,5)],
                      pal[np.random.randint(0,5)]])

# %%
sns.catplot(data=df, kind='boxen', x='math score', y='lunch', col='gender',
            hue='test preparation course', height=3.5, aspect=1.2,
            palette=[pal[np.random.randint(0,5)],
                      pal[np.random.randint(0,5)]])

# %%
sns.catplot(data=df, kind='point', x='math score', y='lunch', col='gender',
            hue='test preparation course', height=3.5,
            palette=[pal[np.random.randint(0,5)],
                      pal[np.random.randint(0,5)]])

# %%
sns.catplot(data=df, kind='violin', x='math score', y='lunch', col='gender',
            hue='test preparation course', height=3.5,
            split=True,
            palette=[pal[np.random.randint(0,5)],
                      pal[np.random.randint(0,5)]])

# %%
sns.catplot(data=df, kind='bar', x='math score', y='lunch', col='gender',
            hue='test preparation course',  height=3.5,
            palette=[pal[np.random.randint(0,5)],
                      pal[np.random.randint(0,5)]])
